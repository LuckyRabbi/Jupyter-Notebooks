# %% [markdown]
# # Mōrena! This is going to be your starting point into the world of New Zealand Statistics
#
# There are a few things you'll need to get started:
# - Check out [NZ.stats](http://nzdotstat.stats.govt.nz/wbos/Index.aspx) and have a look at the [help page](http://nzdotstat.stats.govt.nz/wbos/DotStatGuide/NZStat_Help-Panel.html?_ga=2.88626971.1031089872.1545097847-827032596.1545097847#1) and also this [video tutorial](https://www.youtube.com/watch?v=V531iG5Garw) which should help. Remember that it's all about the data.
# - Learn how to interpret CSV files, I've heard that pandas is a good way to do this.
# - Figure out what you want to know, the primary things you care about are education and the environment but the economy could be interesting to look into too.
# -
#
# I am taking a look at the GHG emissions data from 1990 to 2014 and am going to plot them in matplotlib using pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

ghg = pd.read_csv('ghg2016.csv', index_col=None)

# Set ylimits
plt.ylim(0, 90)

plt.title('NZ GHG Emissions 1990-2014')
plt.plot(ghg['December year'].values, ghg['Total Emissions'].values)
plt.plot(ghg['December year'].values, ghg['Tonnes (million) C02 equivalent '].values)

# %% [markdown]
# That was really easy, I ended up using `.values` method on the csv file to get the whole columns, I couldn't figure out how to access the columns using the regular python syntax.
